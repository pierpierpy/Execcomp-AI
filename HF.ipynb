# %%
from pathlib import Path
import json
from PIL import Image
from datasets import Dataset, Features, Value, Image as HFImage, Sequence

OUTPUT_DIR = Path("output")

# %%
# Trova tutti i documenti con extraction_results.json
records = []

for doc_dir in OUTPUT_DIR.iterdir():
    if not doc_dir.is_dir():
        continue
    
    extraction_file = doc_dir / "extraction_results.json"
    classification_file = doc_dir / "classification_results.json"
    metadata_file = doc_dir / "metadata.json"
    
    # Carica metadata
    if not metadata_file.exists():
        continue
    with open(metadata_file) as f:
        meta = json.load(f)
    
    # Escludi fondi (no SIC)
    if meta.get("sic") == "NULL" or meta.get("sic") is None:
        continue
    
    # Se non ha extraction results, skip
    if not extraction_file.exists() or not classification_file.exists():
        continue
    
    with open(extraction_file) as f:
        extraction = json.load(f)
    with open(classification_file) as f:
        classification = json.load(f)
    
    # Base record con metadati
    base_record = {
        "cik": meta.get("cik"),
        "company": meta.get("company"),
        "year": meta.get("year"),
        "filing_date": meta.get("filing_date"),
        "sic": meta.get("sic"),
        "state_of_inc": meta.get("state_of_inc"),
        "filing_html_index": meta.get("filing_html_index"),
        "accession_number": meta.get("accession_number"),
    }
    
    # Per ogni tabella trovata
    for i, table_info in enumerate(classification.get("tables", [])):
        record = base_record.copy()
        
        # Immagine
        img_path = table_info.get("table", {}).get("img_path", "")
        images_dir = doc_dir / doc_dir.name / "vlm"
        full_img_path = images_dir / img_path
        
        if full_img_path.exists():
            record["table_image"] = str(full_img_path)
        else:
            record["table_image"] = None
        
        # HTML body
        record["table_body"] = table_info.get("table", {}).get("table_body", "")
        
        # Executives (dalla extraction corrispondente)
        if i < len(extraction.get("data", [])):
            execs = extraction["data"][i].get("executives", [])
            record["executives"] = json.dumps(execs)
        else:
            record["executives"] = json.dumps([])
        
        records.append(record)

print(f"Total records: {len(records)}")
# Out:
# Total records: 25

# %%
# Crea dataset HuggingFace
ds = Dataset.from_list(records)

# Cast immagini
ds = ds.cast_column("table_image", HFImage())

print(ds)
print(ds[0])
# Out:
# Dataset({
#     features: ['cik', 'company', 'year', 'filing_date', 'sic', 'state_of_inc', 'filing_html_index', 'accession_number', 'table_image', 'table_body', 'executives'],
#     num_rows: 25
# })
# {'cik': '1315255', 'company': 'GTT Communications, Inc.', 'year': 2018, 'filing_date': '2018-04-30T00:00:00', 'sic': '4813', 'state_of_inc': 'DE', 'filing_html_index': 'https://www.sec.gov/Archives/edgar/data/1315255/0001398344-18-006199-index.html', 'accession_number': '0001398344-18-006199', 'table_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1583x584 at 0x7FFDD97666F0>, 'table_body': '<table><tr><td>Name and Principal Position</td><td>Year</td><td>Salary ($)</td><td>Stock Awards (1) ($)</td><td>Option Awards (1) ($)</td><td>Non-Equity Incentive Plan Compensation (2)</td><td>All Other Compensation(3) ($)</td><td>Total ($)</td></tr><tr><td>H. Brian Thompson,</td><td>2017</td><td>250,000</td><td>350,017</td><td>—</td><td>—</td><td>—</td><td>600,017</td></tr><tr><td>Executive Chairman</td><td>2016</td><td>225,000</td><td>250,002</td><td>—</td><td>—</td><td>—</td><td>475,002</td></tr><tr><td></td><td>2015</td><td>187,500</td><td>150,023</td><td>—</td><td>—</td><td>—</td><td>337,523</td></tr><tr><td>Richard D. Calder, Jr.,</td><td>2017</td><td>525,000</td><td>7,184,996</td><td>—</td><td>520,013</td><td>12,000</td><td>8,242,009</td></tr><tr><td>Chief Executive Officer</td><td>2016</td><td>495,000</td><td>756,242</td><td>165,659</td><td>512,321</td><td>12,000</td><td>1,941,222</td></tr><tr><td>and President</td><td>2015</td><td>450,000</td><td>4,632,410</td><td>279,750</td><td>658,350</td><td>12,000</td><td>6,032,510</td></tr><tr><td>Chris McKee,</td><td>2017</td><td>350,000</td><td>4,554,321</td><td>—</td><td>247,625</td><td>9,000</td><td>5,160,946</td></tr><tr><td>General Counsel, Executive</td><td>2016</td><td>340,000</td><td>359,214</td><td>78,687</td><td>218,398</td><td>9,000</td><td>1,005,299</td></tr><tr><td>Vice President and Secretary</td><td>2015</td><td>310,000</td><td>2,756,937</td><td>125,885</td><td>277,970</td><td>9,000</td><td>3,479,792</td></tr><tr><td>Michael Sicoli,</td><td>2017</td><td>350,000</td><td>4,268,932</td><td>—</td><td>227,815</td><td>9,000</td><td>4,855,747</td></tr><tr><td>Chief Financial Officer</td><td>2016</td><td>340,000</td><td>359,214</td><td>78,687</td><td>216,298</td><td>9,000</td><td>1,003,199</td></tr><tr><td></td><td>2015(4)</td><td>223,160</td><td>3,509,450</td><td>170,095</td><td>207,053</td><td>5,813</td><td>4,115,570</td></tr></table>', 'executives': '[{"name": "H. Brian Thompson", "title": "Executive Chairman", "fiscal_year": 2017, "salary": 250000.0, "bonus": 0, "stock_awards": 350017.0, "option_awards": 0.0, "non_equity_incentive": 0.0, "change_in_pension": 0.0, "other_compensation": 0.0, "total": 600017.0}, {"name": "H. Brian Thompson", "title": "Executive Chairman", "fiscal_year": 2016, "salary": 225000.0, "bonus": 0, "stock_awards": 250002.0, "option_awards": 0.0, "non_equity_incentive": 0.0, "change_in_pension": 0.0, "other_compensation": 0.0, "total": 475002.0}, {"name": "H. Brian Thompson", "title": "Executive Chairman", "fiscal_year": 2015, "salary": 187500.0, "bonus": 0, "stock_awards": 150023.0, "option_awards": 0.0, "non_equity_incentive": 0.0, "change_in_pension": 0.0, "other_compensation": 0.0, "total": 337523.0}, {"name": "Richard D. Calder, Jr.", "title": "Chief Executive Officer and President", "fiscal_year": 2017, "salary": 525000.0, "bonus": 0, "stock_awards": 7184996.0, "option_awards": 0.0, "non_equity_incentive": 520013.0, "change_in_pension": 0.0, "other_compensation": 12000.0, "total": 8242009.0}, {"name": "Richard D. Calder, Jr.", "title": "Chief Executive Officer and President", "fiscal_year": 2016, "salary": 495000.0, "bonus": 0, "stock_awards": 756242.0, "option_awards": 165659.0, "non_equity_incentive": 512321.0, "change_in_pension": 0.0, "other_compensation": 12000.0, "total": 1941222.0}, {"name": "Richard D. Calder, Jr.", "title": "Chief Executive Officer and President", "fiscal_year": 2015, "salary": 450000.0, "bonus": 0, "stock_awards": 4632410.0, "option_awards": 279750.0, "non_equity_incentive": 658350.0, "change_in_pension": 0.0, " ...

# %%
ds.save_to_disk("hf/execcomp-ai-sample")
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 25/25 [00:00<00:00, 990.93 examples/s]

# %%
# Push to HuggingFace
from huggingface_hub import HfApi
api = HfApi()
# Usa token dalla CLI (huggingface-cli login) oppure passa token="hf_..."
ds.push_to_hub("pierjoe/execcomp-ai-sample")
# Out:
# Map: 100%|██████████| 25/25 [00:00<00:00, 1584.60 examples/s]? shards/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 159.89ba/s]
# Processing Files (1 / 1): 100%|██████████| 2.43MB / 2.43MB, 1.74MB/s
# New Data Upload: 100%|██████████| 2.34MB / 2.34MB, 1.67MB/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:02<00:00,  2.21s/ shards]
# CommitInfo(commit_url='https://huggingface.co/datasets/pierjoe/execcomp-ai-sample/commit/0534a48c0e43044e1d81237d760b559c132e18ea', commit_message='Upload dataset', commit_description='', oid='0534a48c0e43044e1d81237d760b559c132e18ea', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/pierjoe/execcomp-ai-sample', endpoint='https://huggingface.co', repo_type='dataset', repo_id='pierjoe/execcomp-ai-sample'), pr_revision=None, pr_num=None)
